# %%
from __future__ import print_function
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import os
import matplotlib.pyplot as plt
plt.switch_backend('agg')
import wfdb
import time
import random
from sklearn.preprocessing import minmax_scale
import sys
from torch.utils.tensorboard import SummaryWriter

# %%
import datetime
import os

def get_current_datetime():
    current_time = datetime.datetime.now()
    
    formatted_time = current_time.strftime("%Y-%m-%d-%H-%M-%S")
    
    return formatted_time

batch_size = 10
data_name = "ptbdb"
exp_name = "Self_ONN_fcanet_Adaptive_16"
seed_num = 42
riqi = get_current_datetime()

result_path = f"result_tran&valid&test/{data_name}/{seed_num}/{exp_name}/{riqi}"

# %% [markdown]
# ## 加载数据

# %%
def intersection(lst1, lst2):

    return list(set(lst1) & set(lst2))


def move_to(patient_id, source, target):
    moved_files = []

    for file_ in source:
        if file_[:10] == patient_id:
            moved_files.append(file_)

    for file_ in moved_files:
        source.remove(file_)
        target.append(file_)


def de_intersection(src1, src2):
    ids1 = [element[:10] for element in src1]
    ids2 = [element[:10] for element in src2]
    intersection_id = intersection(ids1, ids2)
    move_to_src1 = intersection_id[: int(0.5 * len(intersection_id))]
    move_to_src2 = intersection_id[int(0.5 * len(intersection_id)) :]
    for id in move_to_src1:
        move_to(id, src2, src1)
    for id in move_to_src2:
        move_to(id, src1, src2)


def gen_data(seed_num, chns=None):

    # load real data (ptbdb)
    with open("ptbdb_data/RECORDS") as fp:
        lines = fp.readlines()

    files_mi, files_hc = [], []

    for file in lines:
        file_path = "ptbdb_data/" + file[:-1] + ".hea"  # 读取头文件

        # read header to determine class
        if "Myocardial infarction" in open(file_path).read():
            files_mi.append(file)

        if "Healthy control" in open(file_path).read():
            files_hc.append(file)

    # shuffle data (cross-validation)
    print(len(files_mi), len(files_hc))
    np.random.seed(int(seed_num))
    np.random.shuffle(files_mi)
    np.random.shuffle(files_hc)
    # 划分train、valid、test 文件名
    # train_rate = config.TRAIN_RATE
    train_rate = 0.8
    hc_train = files_hc[: int(train_rate * len(files_hc))]
    hc_val_test = files_hc[int(train_rate * len(files_hc)) :]
    mi_train = files_mi[: int(train_rate * len(files_mi))]
    mi_val_test = files_mi[int(train_rate * len(files_mi)) :]

    de_intersection(hc_train, hc_val_test)
    de_intersection(mi_train, mi_val_test)

    hc_val = hc_val_test[: int(0.5 * len(hc_val_test))]
    hc_test = hc_val_test[int(0.5 * len(hc_val_test)) :]
    mi_val = mi_val_test[: int(0.5 * len(mi_val_test))]
    mi_test = mi_val_test[int(0.5 * len(mi_val_test)) :]

    de_intersection(hc_val, hc_test)
    de_intersection(mi_val, mi_test)

    chns = ["i", "ii", "iii", "avr", "avl", "avf", "v1", "v2", "v3", "v4", "v5", "v6"] if chns == "ALL" else chns

    data_hc_train = []
    data_hc_val = []
    data_hc_test = []
    data_mi_train = []
    data_mi_val = []
    data_mi_test = []
    for file in hc_train:
        data = []
        for chn in chns:
            data.append(wfdb.rdsamp("ptbdb_data/" + file[:-1], channel_names=[str(chn)])[0].flatten())
        data_hc_train.append(data)

    for file in hc_val:
        data = []
        for chn in chns:
            data.append(wfdb.rdsamp("ptbdb_data/" + file[:-1], channel_names=[str(chn)])[0].flatten())
        data_hc_val.append(data)

    for file in hc_test:
        data = []
        for chn in chns:
            data.append(wfdb.rdsamp("ptbdb_data/" + file[:-1], channel_names=[str(chn)])[0].flatten())
        data_hc_test.append(data)

    for file in mi_train:
        data = []
        for chn in chns:
            data.append(wfdb.rdsamp("ptbdb_data/" + file[:-1], channel_names=[str(chn)])[0].flatten())
        data_mi_train.append(data)

    for file in mi_val:
        data = []
        for chn in chns:
            data.append(wfdb.rdsamp("ptbdb_data/" + file[:-1], channel_names=[str(chn)])[0].flatten())
        data_mi_val.append(data)

    for file in mi_test:
        data = []
        for chn in chns:
            data.append(wfdb.rdsamp("ptbdb_data/" + file[:-1], channel_names=[str(chn)])[0].flatten())
        data_mi_test.append(data)
    print(len(hc_train))
    print(len(hc_val))
    print(len(hc_test)) 
    print(len(mi_train))
    print(len(mi_val))    
    print(len(mi_test))

    data_hc_train = np.array(data_hc_train, dtype=object)
    data_hc_val = np.array(data_hc_val, dtype=object)
    data_hc_test = np.array(data_hc_test, dtype=object)
    data_mi_train = np.array(data_mi_train, dtype=object)
    data_mi_val = np.array(data_mi_val, dtype=object)
    data_mi_test = np.array(data_mi_test, dtype=object)
    data_train = (data_hc_train, data_mi_train)
    data_val = (data_hc_val, data_mi_val)
    data_test = (data_hc_test, data_mi_test)
    return [data_train, data_val, data_test]

train_data,val_data,test_data = gen_data(seed_num,chns = ['vz', 'v6'])
# Out:
# 368 80
# 64
# 7
# 9
# 265
# 59
# 44

# %%
def get_batch(batch_size,split='train'):
    # batch_size = config.BATCH_SIZE
    # window_size = config.WINDOW_SIZE
    batch_size = batch_size
    window_size = 10000
    data_unhealthy_train, data_healthy_train = train_data
    data_unhealthy_val, data_healthy_val = val_data
    data_unhealthy_test, data_healthy_test = test_data
    if split == "train":
        unhealthy_indices = random.sample(list(np.arange(len(data_unhealthy_train))), k=int(batch_size / 2))
        healthy_indices = random.sample(list(np.arange(len(data_healthy_train))), k=int(batch_size / 2))
        mi_batch = data_unhealthy_train[unhealthy_indices]
        hc_batch = data_healthy_train[healthy_indices]
    elif split == "val":
        unhealthy_indices = random.sample(list(np.arange(len(data_unhealthy_val))), k=int(batch_size / 2))
        healthy_indices = random.sample(list(np.arange(len(data_healthy_val))), k=int(batch_size / 2))
        mi_batch = data_unhealthy_val[unhealthy_indices]
        hc_batch = data_healthy_val[healthy_indices]
    elif split == "test":
        unhealthy_indices = random.sample(list(np.arange(len(data_unhealthy_test))), k=int(batch_size / 2))
        healthy_indices = random.sample(list(np.arange(len(data_healthy_test))), k=int(batch_size / 2))
        mi_batch = data_unhealthy_test[unhealthy_indices]
        hc_batch = data_healthy_test[healthy_indices]

    batch_x = []
    chn_num = mi_batch.shape[1]
    for sample in mi_batch:

        start = random.choice(np.arange(len(sample[0]) - window_size))

        # normalize
        # normalized_1 = minmax_scale(sample[0][start : start + window_size])
        # normalized_2 = minmax_scale(sample[1][start : start + window_size])
        # normalized = np.array((normalized_1, normalized_2))

        normalized_list = []
        for i in range(chn_num):
            normalized_list.append(minmax_scale(sample[i][start : start + window_size]))
        normalized = np.array(normalized_list)

        batch_x.append(normalized)

    for sample in hc_batch:

        start = random.choice(np.arange(len(sample[0]) - window_size))

        # normalize
        # normalized_1 = minmax_scale(sample[0][start : start + window_size])
        # normalized_2 = minmax_scale(sample[1][start : start + window_size])
        # normalized = np.array((normalized_1, normalized_2))
        normalized_list = []
        for i in range(chn_num):
            normalized_list.append(minmax_scale(sample[i][start : start + window_size]))
        normalized = np.array(normalized_list)

        batch_x.append(normalized)

    # 0.1 for unhealthy, 0.9 for healthy
    batch_y = [0.1 for _ in range(int(batch_size / 2))]
    for _ in range(int(batch_size / 2)):
        batch_y.append(0.9)

    indices = np.arange(len(batch_y))
    np.random.shuffle(indices)

    batch_x = np.array(batch_x)
    batch_y = np.array(batch_y)

    batch_x = batch_x[indices]
    batch_y = batch_y[indices]

    print(type(batch_x))
    print(type(batch_y))
    print(batch_x.shape)
    print(batch_y.shape)
    print(batch_x.dtype)
    print(type(batch_y[0]))
    print(batch_y)

    batch_x = np.reshape(batch_x, (-1, chn_num, window_size))
    batch_x = torch.from_numpy(batch_x)
    batch_x = batch_x.float().cuda()
    batch_x = batch_x.float()

    batch_y = np.reshape(batch_y, (-1, 1))
    batch_y = torch.from_numpy(batch_y)
    batch_y = batch_y.float().cuda()
    batch_y = batch_y.float()

    return batch_x, batch_y

# %%
batch_x, batch_y = get_batch(batch_size, split='train')
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# (10, 2, 10000)
# (10,)
# float64
# <class 'numpy.float64'>
# [0.1 0.9 0.1 0.1 0.9 0.1 0.1 0.9 0.9 0.9]

# %%
for iters in range(1):
    batch_x, batch_y = get_batch(10, split='train')
    print("Batch X Min Value:", batch_x.min().item())
    print("Batch X Max Value:", batch_x.max().item())
    # print(batch_x)
# Out:
# Batch X Min Value: 0.0
# Batch X Max Value: 1.0

# %% [markdown]
# ## tarin

# %%
import os
from Models.self_onn_fcanet_ada_10000 import self_onn_fcanet_ada_10000
from Models.self_onn_fcanet_ada_10000_base_length import self_onn_fcanet_ada_10000_base_length
from Models.self_onn_fcanet import self_onn_fcanet
from Models.self_onn import self_onn
from Models.CNN import CNN
# results_path = 'results/ConvNetQuake'
results_path = os.path.join(result_path,'results')

model = self_onn_fcanet_ada_10000_base_length().to('cuda:0')
model.cuda()

model = nn.DataParallel(model, device_ids=[0])

optimizer = torch.optim.Adam(model.parameters(), lr=1.0e-4)
criterion = nn.BCELoss()
writer = SummaryWriter(log_dir=results_path)

# %%
import pandas as pd
import os
# num_iters = 35000
num_iters = 35000
batch_size = 10
acc_values = []
acc_values_train = []

loss_values = []
loss_values_train = []
# 初始化最高准确率为 0
best_acc = 0
best_iter = 0

results_file_path_plot = os.path.join(result_path, 'plot')
os.makedirs(results_file_path_plot, exist_ok=True)
results_file_path = os.path.join(results_file_path_plot, 'training_results.txt')


best_loss = float('inf')  # 设置初始最低损失为无穷大
saved_models = []  # 用于存储保存的模型路径
saved_models_test = []  # 用于存储测试集上最佳模型路径
max_saved_models = 10  # 最多保存的模型数量
best_test_acc = 0

# 修改后的训练过程
for iters in range(num_iters):
    batch_x, batch_y = get_batch(batch_size, split='train')
    batch_x, batch_y = batch_x.to('cuda:0'), batch_y.to('cuda:0')

    y_pred = model(batch_x)

    loss = criterion(y_pred, batch_y)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # validation
    if iters % 100 == 0 and iters != 0:

        writer.add_scalar('Loss/train', loss, iters)
        print('Loss/train=', loss.cpu().detach().numpy())

        with torch.no_grad():

            # validation
            iterations = 100
            avg_acc = 0
            total_val_loss = 0  # 用于累计验证损失   +++

            for _ in range(iterations):
                batch_x, batch_y = get_batch(batch_size, split='val')
                
                cleaned = model(batch_x)

                # 计算验证损失
                val_loss = criterion(cleaned, batch_y)   # ++
                total_val_loss += val_loss.item()   # ++

                count = 0
                acc = 0
                for num in cleaned:
                    if int(torch.round(num)) == int(torch.round(batch_y[count])):
                        acc += 10
                    count += 1
                avg_acc += acc

            avg_acc = avg_acc / iterations
            avg_val_loss = total_val_loss / iterations  # 计算平均验证损失   
            acc_values.append(avg_acc)
            loss_values.append(avg_val_loss)
            writer.add_scalar('Accuracy/val', avg_acc, iters)
            writer.add_scalar('Loss/val', avg_val_loss, iters)  # 记录验证损失 
            print(f'Accuracy/val={avg_acc}         Loss/val={avg_val_loss}')
            # print(f'Accuracy/val=', avg_acc)
            # print('Loss/val=', avg_val_loss)  # 打印验证损失 

            # 更新最高准确率及其迭代次数
            if avg_acc > best_acc:
                best_acc = avg_acc
                best_iter = iters
                # 保存当前最高准确率到指定文件
                valid_path = os.path.join(result_path, 'valid')
                os.makedirs(valid_path, exist_ok=True)
                # with open(os.path.join(results_path, 'best_accuracy.txt'), 'w') as f:
                with open(os.path.join(valid_path, 'best_valid_accuracy.txt'), 'a') as f:
                    f.write(f"Iteration: {best_iter}   Best Accuracy: {best_acc}\n")  # 在同一行输出
                    
            # train_set
            iterations = 100
            avg_acc_train = 0

            total_train_loss = 0 

            for _ in range(iterations):
                batch_x, batch_y = get_batch(batch_size, split='train')
                cleaned = model(batch_x)
                # 计算训练损失
                train_loss = criterion(cleaned, batch_y)
                total_train_loss += train_loss.item()  # 累加训练损失

                count = 0
                acc = 0
                for num in cleaned:
                    if int(torch.round(num)) == int(torch.round(batch_y[count])):
                        acc += 10
                    count += 1
                avg_acc_train += acc
            

            avg_acc_train = avg_acc_train / iterations
            avg_train_loss = total_train_loss / iterations  # 计算平均训练损失
            acc_values_train.append(avg_acc_train)
            loss_values_train.append(avg_train_loss)
            writer.add_scalar('Accuracy/train', avg_acc_train, iters)
            writer.add_scalar('Loss/train', avg_train_loss, iters)  # 记录训练损失
            with open(results_file_path, 'a') as f:
                f.write(f"Iteration: {iters}, ")
                f.write(f"Train Accuracy: {avg_acc_train}, Train Loss: {avg_train_loss}, ")
                f.write(f"Validation Accuracy: {avg_acc}, Validation Loss: {avg_val_loss}\n")

            print(f'Accuracy/train={avg_acc_train}         Loss/train={avg_train_loss}')


    # 保存模型和图表
    if iters % 100 == 0 and iters != 0:
        print("this is the iters:", iters)
        torch.save(model.state_dict(), os.path.join(results_path, 'CNQ_model.pth'))
        torch.save(optimizer.state_dict(), os.path.join(results_path, 'CNQ_optim.opt'))

        fig = plt.figure(figsize=(18, 12))
        plt.title(iters)
        plt.plot(acc_values, color="blue")
        plt.plot(acc_values_train, color="red")
        plt.grid()
        fig.savefig(os.path.join(results_path, "CNQ_model_acc.jpeg"))


        fig = plt.figure(figsize=(18, 12))
        plt.title(iters)
        plt.plot(loss_values, color="blue")
        plt.plot(loss_values_train, color="red")
        plt.grid()
        fig.savefig(os.path.join(results_path, "CNQ_model_loss.jpeg"))

        
        checkpoint_path = os.path.join(result_path, 'checkpoint')
        os.makedirs(checkpoint_path, exist_ok=True)
        model_path = os.path.join(checkpoint_path, f'model_{iters}.pth')
        torch.save(model.state_dict(), model_path)

        df = pd.DataFrame({
            'acc_values': acc_values,
            'acc_values_train': acc_values_train,
            'loss_values': loss_values,
            'loss_values_train': loss_values_train
        })

        # 设置文件保存路径
        save_path = os.path.join(results_path, "training_data.csv")

        # 保存为 CSV
        df.to_csv(save_path, index=False)
plt.close()
# Out:
# Loss/train= 0.6282875
# Accuracy/val=60.8         Loss/val=0.6809571173787117
# Accuracy/train=74.9         Loss/train=0.6267704480886459
# this is the iters: 100
# Loss/train= 0.5422954
# Accuracy/val=76.3         Loss/val=0.629227868616581
# Accuracy/train=75.5         Loss/train=0.6153197067975998
# this is the iters: 200
# Loss/train= 0.72720116
# Accuracy/val=60.6         Loss/val=0.6983036941289902
# Accuracy/train=77.1         Loss/train=0.5875185477733612
# this is the iters: 300
# Loss/train= 0.6357752
# Accuracy/val=57.6         Loss/val=0.7008736288547516
# Accuracy/train=76.3         Loss/train=0.5933857953548431
# this is the iters: 400
# Loss/train= 0.53312486
# Accuracy/val=72.2         Loss/val=0.6136864393949508
# Accuracy/train=76.1         Loss/train=0.5935234525799751
# this is the iters: 500
# Loss/train= 0.63007146
# Accuracy/val=58.4         Loss/val=0.7249930369853973
# Accuracy/train=79.9         Loss/train=0.5642028626799583
# this is the iters: 600
# Loss/train= 0.5953681
# Accuracy/val=75.4         Loss/val=0.6353591114282608
# Accuracy/train=81.6         Loss/train=0.5478947603702545
# this is the iters: 700
# Loss/train= 0.5451395
# Accuracy/val=76.6         Loss/val=0.622121216058731
# Accuracy/train=82.6         Loss/train=0.5164102202653885
# this is the iters: 800
# Loss/train= 0.48675045
# Accuracy/val=80.1         Loss/val=0.6028735792636871
# Accuracy/train=82.1         Loss/train=0.5431380268931388
# this is the iters: 900
# Loss/train= 0.41641042
# Accuracy/val=76.1         Loss/val=0.6018285152316093
# Accuracy/train=81.6         Loss/train=0.5171771654486657
# this is the iters: 1000
# Loss/train= 0.5705452
# Accuracy/val=82.0         Loss/val=0.5860555672645569
# Accuracy/train=87.9         Loss/train=0.4825510761141777
# this is the iters: 1100
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\1450135179.py:140: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figsize=(18, 12))
# Loss/train= 0.5590194
# Accuracy/val=78.1         Loss/val=0.6031525564193726
# Accuracy/train=87.9         Loss/train=0.47582651913166046
# this is the iters: 1200
# Loss/train= 0.55510825
# Accuracy/val=60.3         Loss/val=0.7926339399814606
# Accuracy/train=79.4         Loss/train=0.5459167221188546
# this is the iters: 1300
# Loss/train= 0.48603162
# Accuracy/val=81.5         Loss/val=0.5556214997172355
# Accuracy/train=88.6         Loss/train=0.47322058826684954
# this is the iters: 1400
# Loss/train= 0.49021488
# Accuracy/val=81.4         Loss/val=0.5607758846879005
# Accuracy/train=87.8         Loss/train=0.47910209238529206
# this is the iters: 1500
# Loss/train= 0.42743436
# Accuracy/val=78.3         Loss/val=0.5820122295618058
# Accuracy/train=88.4         Loss/train=0.46636523634195326
# this is the iters: 1600
# Loss/train= 0.5724884
# Accuracy/val=84.5         Loss/val=0.562373631298542
# Accuracy/train=89.1         Loss/train=0.4685429164767265
# this is the iters: 1700
# Loss/train= 0.49128228
# Accuracy/val=71.5         Loss/val=0.6368474742770195
# Accuracy/train=88.6         Loss/train=0.46738935470581056
# this is the iters: 1800
# Loss/train= 0.36141953
# Accuracy/val=81.1         Loss/val=0.5894295927882195
# Accuracy/train=89.8         Loss/train=0.4601870936155319
# this is the iters: 1900
# Loss/train= 0.5300269
# Accuracy/val=71.9         Loss/val=0.6175581470131875
# Accuracy/train=87.3         Loss/train=0.47258830070495605
# this is the iters: 2000
# Loss/train= 0.36505812
# Accuracy/val=84.1         Loss/val=0.5273034045100212
# Accuracy/train=91.7         Loss/train=0.4468235257267952
# this is the iters: 2100
# Loss/train= 0.5128209
# Accuracy/val=83.1         Loss/val=0.5332582280039787
# Accuracy/train=91.6         Loss/train=0.4374025931954384
# this is the iters: 2200
# Loss/train= 0.45209852
# Accuracy/val=83.9         Loss/val=0.542476672232151
# Accuracy/train=90.5         Loss/train=0.4497327888011932
# this is the iters: 2300
# Loss/train= 0.3678964
# Accuracy/val=82.8         Loss/val=0.561348865032196
# Accuracy/train=92.6         Loss/train=0.4254178094863892
# this is the iters: 2400
# Loss/train= 0.4456574
# Accuracy/val=81.8         Loss/val=0.5583956035971641
# Accuracy/train=91.4         Loss/train=0.4361383640766144
# this is the iters: 2500
# Loss/train= 0.4901262
# Accuracy/val=85.3         Loss/val=0.5069831281900405
# Accuracy/train=92.9         Loss/train=0.42156764984130857
# this is the iters: 2600
# Loss/train= 0.66388774
# Accuracy/val=83.9         Loss/val=0.5304273149371147
# Accuracy/train=94.6         Loss/train=0.4139731851220131
# this is the iters: 2700
# Loss/train= 0.41349593
# Accuracy/val=84.9         Loss/val=0.5209933257102967
# Accuracy/train=94.8         Loss/train=0.4028107953071594
# this is the iters: 2800
# Loss/train= 0.46142474
# Accuracy/val=79.2         Loss/val=0.5581757897138595
# Accuracy/train=92.6         Loss/train=0.4315765610337257
# this is the iters: 2900
# Loss/train= 0.4509604
# Accuracy/val=85.6         Loss/val=0.5311162757873535
# Accuracy/train=93.3         Loss/train=0.4255092087388039
# this is the iters: 3000
# Loss/train= 0.6106412
# Accuracy/val=87.1         Loss/val=0.5139754658937454
# Accuracy/train=93.3         Loss/train=0.4187323170900345
# this is the iters: 3100
# Loss/train= 0.47540513
# Accuracy/val=83.6         Loss/val=0.5432860743999481
# Accuracy/train=92.7         Loss/train=0.4293998536467552
# this is the iters: 3200
# Loss/train= 0.35741562
# Accuracy/val=81.5         Loss/val=0.5811339521408081
# Accuracy/train=93.5         Loss/train=0.4232531437277794
# this is the iters: 3300
# Loss/train= 0.4419631
# Accuracy/val=84.0         Loss/val=0.5228391316533089
# Accuracy/train=95.6         Loss/train=0.4015419474244118
# this is the iters: 3400
# Loss/train= 0.5105198
# Accuracy/val=75.0         Loss/val=0.6150385358929634
# Accuracy/train=91.4         Loss/train=0.42691423892974856
# this is the iters: 3500
# Loss/train= 0.35794058
# Accuracy/val=86.5         Loss/val=0.5123947459459305
# Accuracy/train=94.0         Loss/train=0.4103200152516365
# this is the iters: 3600
# Loss/train= 0.35933244
# Accuracy/val=83.3         Loss/val=0.5367946848273277
# Accuracy/train=92.2         Loss/train=0.42203392207622525
# this is the iters: 3700
# Loss/train= 0.38986865
# Accuracy/val=84.5         Loss/val=0.5305728638172149
# Accuracy/train=96.7         Loss/train=0.3857106816768646
# this is the iters: 3800
# Loss/train= 0.42257786
# Accuracy/val=84.7         Loss/val=0.5280689659714699
# Accuracy/train=95.6         Loss/train=0.39025802224874495
# this is the iters: 3900
# Loss/train= 0.37037888
# Accuracy/val=82.3         Loss/val=0.5221814966201782
# Accuracy/train=95.0         Loss/train=0.3968158158659935
# this is the iters: 4000
# Loss/train= 0.47833037
# Accuracy/val=85.4         Loss/val=0.4962495881319046
# Accuracy/train=95.1         Loss/train=0.39963905811309813
# this is the iters: 4100
# Loss/train= 0.34942064
# Accuracy/val=83.4         Loss/val=0.5328317311406136
# Accuracy/train=95.1         Loss/train=0.39788270115852353
# this is the iters: 4200
# Loss/train= 0.4293697
# Accuracy/val=85.2         Loss/val=0.5098627039790153
# Accuracy/train=94.5         Loss/train=0.4090887913107872
# this is the iters: 4300
# Loss/train= 0.38755536
# Accuracy/val=86.4         Loss/val=0.5143367698788643
# Accuracy/train=94.6         Loss/train=0.4023404824733734
# this is the iters: 4400
# Loss/train= 0.3623387
# Accuracy/val=82.0         Loss/val=0.5619461193680764
# Accuracy/train=93.8         Loss/train=0.4115404784679413
# this is the iters: 4500
# Loss/train= 0.40109548
# Accuracy/val=81.3         Loss/val=0.5458622866868973
# Accuracy/train=95.0         Loss/train=0.39892686396837235
# this is the iters: 4600
# Loss/train= 0.33796036
# Accuracy/val=87.0         Loss/val=0.5037991768121719
# Accuracy/train=94.2         Loss/train=0.3992112538218498
# this is the iters: 4700
# Loss/train= 0.38236997
# Accuracy/val=83.0         Loss/val=0.5479611396789551
# Accuracy/train=96.0         Loss/train=0.3922474071383476
# this is the iters: 4800
# Loss/train= 0.3420814
# Accuracy/val=88.0         Loss/val=0.48440044462680815
# Accuracy/train=96.4         Loss/train=0.3779630786180496
# this is the iters: 4900
# Loss/train= 0.45974025
# Accuracy/val=84.0         Loss/val=0.5216959306597709
# Accuracy/train=95.9         Loss/train=0.3872108009457588
# this is the iters: 5000
# Loss/train= 0.4511303
# Accuracy/val=78.8         Loss/val=0.5601546823978424
# Accuracy/train=97.7         Loss/train=0.37885907024145127
# this is the iters: 5100
# Loss/train= 0.39694306
# Accuracy/val=84.5         Loss/val=0.5225268563628197
# Accuracy/train=96.1         Loss/train=0.38692427694797515
# this is the iters: 5200
# Loss/train= 0.36994216
# Accuracy/val=85.5         Loss/val=0.5126681941747665
# Accuracy/train=96.7         Loss/train=0.37458508998155593
# this is the iters: 5300
# Loss/train= 0.38606697
# Accuracy/val=86.5         Loss/val=0.49485413640737536
# Accuracy/train=96.3         Loss/train=0.3832406899333
# this is the iters: 5400
# Loss/train= 0.36965734
# Accuracy/val=85.5         Loss/val=0.5372038605809212
# Accuracy/train=96.9         Loss/train=0.3755363181233406
# this is the iters: 5500
# Loss/train= 0.44381
# Accuracy/val=88.6         Loss/val=0.48109548777341843
# Accuracy/train=97.1         Loss/train=0.3802873393893242
# this is the iters: 5600
# Loss/train= 0.43337575
# Accuracy/val=82.8         Loss/val=0.5327812668681144
# Accuracy/train=96.4         Loss/train=0.37615253269672394
# this is the iters: 5700
# Loss/train= 0.33561867
# Accuracy/val=87.2         Loss/val=0.4945630061626434
# Accuracy/train=96.2         Loss/train=0.3804642724990845
# this is the iters: 5800
# Loss/train= 0.3648073
# Accuracy/val=86.7         Loss/val=0.49750403940677645
# Accuracy/train=97.5         Loss/train=0.3687667950987816
# this is the iters: 5900
# Loss/train= 0.36816555
# Accuracy/val=79.3         Loss/val=0.5451624083518982
# Accuracy/train=96.0         Loss/train=0.3886317998170853
# this is the iters: 6000
# Loss/train= 0.39744464
# Accuracy/val=74.2         Loss/val=0.6195938658714294
# Accuracy/train=96.8         Loss/train=0.3793477612733841
# this is the iters: 6100
# Loss/train= 0.34806234
# Accuracy/val=86.1         Loss/val=0.5216211840510369
# Accuracy/train=95.0         Loss/train=0.3979104954004288
# this is the iters: 6200
# Loss/train= 0.34053522
# Accuracy/val=80.7         Loss/val=0.5471432545781135
# Accuracy/train=96.0         Loss/train=0.39507160425186155
# this is the iters: 6300
# Loss/train= 0.3650241
# Accuracy/val=86.5         Loss/val=0.526071939766407
# Accuracy/train=97.7         Loss/train=0.36884775787591934
# this is the iters: 6400
# Loss/train= 0.38873196
# Accuracy/val=80.0         Loss/val=0.5571535465121269
# Accuracy/train=96.9         Loss/train=0.3739019292593002
# this is the iters: 6500
# Loss/train= 0.3996779
# Accuracy/val=83.9         Loss/val=0.5349194583296776
# Accuracy/train=96.9         Loss/train=0.3727200162410736
# this is the iters: 6600
# Loss/train= 0.34887108
# Accuracy/val=83.4         Loss/val=0.5163186356425286
# Accuracy/train=98.1         Loss/train=0.3691250973939896
# this is the iters: 6700
# Loss/train= 0.37112984
# Accuracy/val=84.9         Loss/val=0.5082663363218307
# Accuracy/train=97.2         Loss/train=0.36931723535060884
# this is the iters: 6800
# Loss/train= 0.3502343
# Accuracy/val=87.1         Loss/val=0.5061470630764962
# Accuracy/train=97.3         Loss/train=0.3683536288142204
# this is the iters: 6900
# Loss/train= 0.49643394
# Accuracy/val=79.9         Loss/val=0.5441892516613006
# Accuracy/train=97.5         Loss/train=0.3723102268576622
# this is the iters: 7000
# Loss/train= 0.3942266
# Accuracy/val=78.8         Loss/val=0.5423849973082543
# Accuracy/train=97.1         Loss/train=0.37608881056308746
# this is the iters: 7100
# Loss/train= 0.44331786
# Accuracy/val=86.0         Loss/val=0.520551535487175
# Accuracy/train=97.5         Loss/train=0.3697675633430481
# this is the iters: 7200
# Loss/train= 0.3408197
# Accuracy/val=85.4         Loss/val=0.5161696591973305
# Accuracy/train=97.3         Loss/train=0.36900694489479063
# this is the iters: 7300
# Loss/train= 0.36596337
# Accuracy/val=86.4         Loss/val=0.5289197137951851
# Accuracy/train=97.9         Loss/train=0.3626579234004021
# this is the iters: 7400
# Loss/train= 0.34177577
# Accuracy/val=88.8         Loss/val=0.48764995753765106
# Accuracy/train=98.8         Loss/train=0.358339911699295
# this is the iters: 7500
# Loss/train= 0.4440143
# Accuracy/val=84.0         Loss/val=0.5348565429449081
# Accuracy/train=97.4         Loss/train=0.37367343485355375
# this is the iters: 7600
# Loss/train= 0.3348331
# Accuracy/val=87.6         Loss/val=0.5010697227716446
# Accuracy/train=97.9         Loss/train=0.3652873581647873
# this is the iters: 7700
# Loss/train= 0.34136438
# Accuracy/val=87.0         Loss/val=0.502424665093422
# Accuracy/train=98.3         Loss/train=0.36720847576856613
# this is the iters: 7800
# Loss/train= 0.3957572
# Accuracy/val=86.6         Loss/val=0.5124088507890702
# Accuracy/train=98.4         Loss/train=0.3582201552391052
# this is the iters: 7900
# Loss/train= 0.3793819
# Accuracy/val=86.1         Loss/val=0.5120232403278351
# Accuracy/train=98.2         Loss/train=0.3598609808087349
# this is the iters: 8000
# Loss/train= 0.3488308
# Accuracy/val=81.8         Loss/val=0.5198194414377213
# Accuracy/train=93.6         Loss/train=0.40975574642419815
# this is the iters: 8100
# Loss/train= 0.38801274
# Accuracy/val=89.1         Loss/val=0.496914214193821
# Accuracy/train=97.8         Loss/train=0.36093861013650896
# this is the iters: 8200
# Loss/train= 0.3597529
# Accuracy/val=76.9         Loss/val=0.5960429739952088
# Accuracy/train=97.9         Loss/train=0.3641934019327164
# this is the iters: 8300
# Loss/train= 0.35869178
# Accuracy/val=89.3         Loss/val=0.4750053033232689
# Accuracy/train=99.3         Loss/train=0.3565334802865982
# this is the iters: 8400
# Loss/train= 0.34704283
# Accuracy/val=86.5         Loss/val=0.5185309559106827
# Accuracy/train=98.2         Loss/train=0.3606345248222351
# this is the iters: 8500
# Loss/train= 0.35225776
# Accuracy/val=87.0         Loss/val=0.5075573965907096
# Accuracy/train=98.6         Loss/train=0.3564114195108414
# this is the iters: 8600
# Loss/train= 0.3571441
# Accuracy/val=83.0         Loss/val=0.5131817156076431
# Accuracy/train=98.8         Loss/train=0.35757472485303876
# this is the iters: 8700
# Loss/train= 0.33911824
# Accuracy/val=83.7         Loss/val=0.5490861317515373
# Accuracy/train=98.3         Loss/train=0.35595803886651994
# this is the iters: 8800
# Loss/train= 0.34690687
# Accuracy/val=84.6         Loss/val=0.5247560280561447
# Accuracy/train=98.6         Loss/train=0.35483883023262025
# this is the iters: 8900
# Loss/train= 0.34840372
# Accuracy/val=88.6         Loss/val=0.4954764479398727
# Accuracy/train=98.3         Loss/train=0.3581399717926979
# this is the iters: 9000
# Loss/train= 0.34718272
# Accuracy/val=88.9         Loss/val=0.4890740296244621
# Accuracy/train=98.6         Loss/train=0.3606614455580711
# this is the iters: 9100
# Loss/train= 0.34764647
# Accuracy/val=89.2         Loss/val=0.4819042956829071
# Accuracy/train=99.4         Loss/train=0.3537032476067543
# this is the iters: 9200
# Loss/train= 0.3659512
# Accuracy/val=81.9         Loss/val=0.5657978817820549
# Accuracy/train=99.0         Loss/train=0.35901978731155393
# this is the iters: 9300
# Loss/train= 0.35758528
# Accuracy/val=88.1         Loss/val=0.5015856078267098
# Accuracy/train=98.4         Loss/train=0.36099829196929933
# this is the iters: 9400
# Loss/train= 0.35584375
# Accuracy/val=86.2         Loss/val=0.49388265699148176
# Accuracy/train=99.4         Loss/train=0.35540560811758043
# this is the iters: 9500
# Loss/train= 0.35536325
# Accuracy/val=90.0         Loss/val=0.4790316617488861
# Accuracy/train=98.4         Loss/train=0.36090907841920855
# this is the iters: 9600
# Loss/train= 0.3573775
# Accuracy/val=89.1         Loss/val=0.5035046344995499
# Accuracy/train=99.3         Loss/train=0.3519657525420189
# this is the iters: 9700
# Loss/train= 0.35707387
# Accuracy/val=91.5         Loss/val=0.45211042284965514
# Accuracy/train=99.4         Loss/train=0.352587970495224
# this is the iters: 9800
# Loss/train= 0.33747643
# Accuracy/val=87.1         Loss/val=0.5027235957980156
# Accuracy/train=99.6         Loss/train=0.3492351907491684
# this is the iters: 9900
# Loss/train= 0.3520961
# Accuracy/val=88.3         Loss/val=0.4911938747763634
# Accuracy/train=99.5         Loss/train=0.3530345231294632
# this is the iters: 10000
# Loss/train= 0.34781203
# Accuracy/val=89.7         Loss/val=0.5077282029390335
# Accuracy/train=99.4         Loss/train=0.3492006868124008
# this is the iters: 10100
# Loss/train= 0.34298405
# Accuracy/val=88.0         Loss/val=0.4976237344741821
# Accuracy/train=98.7         Loss/train=0.3563661739230156
# this is the iters: 10200
# Loss/train= 0.3374153
# Accuracy/val=89.6         Loss/val=0.4957988819479942
# Accuracy/train=99.1         Loss/train=0.3509910321235657
# this is the iters: 10300
# Loss/train= 0.3473316
# Accuracy/val=90.0         Loss/val=0.5040152826905251
# Accuracy/train=99.4         Loss/train=0.3516742867231369
# this is the iters: 10400
# Loss/train= 0.3285664
# Accuracy/val=78.2         Loss/val=0.5572396889328957
# Accuracy/train=99.6         Loss/train=0.3498473778367043
# this is the iters: 10500
# Loss/train= 0.33897856
# Accuracy/val=87.2         Loss/val=0.4945118120312691
# Accuracy/train=99.7         Loss/train=0.3468912079930305
# this is the iters: 10600
# Loss/train= 0.3417306
# Accuracy/val=89.2         Loss/val=0.4964994043111801
# Accuracy/train=99.2         Loss/train=0.35113980650901794
# this is the iters: 10700
# Loss/train= 0.34475374
# Accuracy/val=85.1         Loss/val=0.5464706733822823
# Accuracy/train=99.2         Loss/train=0.34869234323501586
# this is the iters: 10800
# Loss/train= 0.3736516
# Accuracy/val=87.1         Loss/val=0.5203622850775719
# Accuracy/train=99.6         Loss/train=0.34683960288763044
# this is the iters: 10900
# Loss/train= 0.3336854
# Accuracy/val=84.2         Loss/val=0.5312138369679451
# Accuracy/train=99.4         Loss/train=0.3483011680841446
# this is the iters: 11000
# Loss/train= 0.3621569
# Accuracy/val=86.4         Loss/val=0.49960217118263245
# Accuracy/train=99.0         Loss/train=0.3580680012702942
# this is the iters: 11100
# Loss/train= 0.33239606
# Accuracy/val=88.6         Loss/val=0.5068424645066262
# Accuracy/train=98.8         Loss/train=0.3551615384221077
# this is the iters: 11200
# Loss/train= 0.3553116
# Accuracy/val=90.0         Loss/val=0.49928240329027174
# Accuracy/train=98.2         Loss/train=0.3640130445361137
# this is the iters: 11300
# Loss/train= 0.34364864
# Accuracy/val=91.0         Loss/val=0.48288616389036176
# Accuracy/train=99.6         Loss/train=0.34841817647218704
# this is the iters: 11400
# Loss/train= 0.34200838
# Accuracy/val=87.3         Loss/val=0.5154273635149003
# Accuracy/train=99.8         Loss/train=0.34575572192668913
# this is the iters: 11500
# Loss/train= 0.33268464
# Accuracy/val=89.0         Loss/val=0.5040368986129761
# Accuracy/train=99.6         Loss/train=0.3476542070508003
# this is the iters: 11600
# Loss/train= 0.3378864
# Accuracy/val=90.5         Loss/val=0.46828092008829114
# Accuracy/train=99.2         Loss/train=0.3497560441493988
# this is the iters: 11700
# Loss/train= 0.3431008
# Accuracy/val=79.3         Loss/val=0.5669700688123703
# Accuracy/train=99.5         Loss/train=0.3495219975709915
# this is the iters: 11800
# Loss/train= 0.32979152
# Accuracy/val=90.1         Loss/val=0.49193841010332107
# Accuracy/train=99.3         Loss/train=0.34676103323698043
# this is the iters: 11900
# Loss/train= 0.33355233
# Accuracy/val=90.4         Loss/val=0.4979293990135193
# Accuracy/train=99.3         Loss/train=0.3528112888336182
# this is the iters: 12000
# Loss/train= 0.33911338
# Accuracy/val=85.0         Loss/val=0.5075296780467033
# Accuracy/train=99.6         Loss/train=0.3461568534374237
# this is the iters: 12100
# Loss/train= 0.36350158
# Accuracy/val=89.6         Loss/val=0.4957885667681694
# Accuracy/train=99.2         Loss/train=0.3492474675178528
# this is the iters: 12200
# Loss/train= 0.3537887
# Accuracy/val=83.2         Loss/val=0.5074336874485016
# Accuracy/train=99.8         Loss/train=0.3469511339068413
# this is the iters: 12300
# Loss/train= 0.3295775
# Accuracy/val=87.7         Loss/val=0.5225082123279572
# Accuracy/train=99.3         Loss/train=0.3496637827157974
# this is the iters: 12400
# Loss/train= 0.33184457
# Accuracy/val=86.8         Loss/val=0.5123402389883995
# Accuracy/train=99.4         Loss/train=0.34919123351573944
# this is the iters: 12500
# Loss/train= 0.3540469
# Accuracy/val=88.1         Loss/val=0.5236558619141579
# Accuracy/train=99.7         Loss/train=0.341787531375885
# this is the iters: 12600
# Loss/train= 0.3403365
# Accuracy/val=88.8         Loss/val=0.4861537843942642
# Accuracy/train=99.4         Loss/train=0.3450349172949791
# this is the iters: 12700
# Loss/train= 0.33800316
# Accuracy/val=88.9         Loss/val=0.49629362165927887
# Accuracy/train=99.6         Loss/train=0.345007396042347
# this is the iters: 12800
# Loss/train= 0.3929314
# Accuracy/val=88.0         Loss/val=0.513057647049427
# Accuracy/train=99.6         Loss/train=0.34639015287160874
# this is the iters: 12900
# Loss/train= 0.35327682
# Accuracy/val=87.3         Loss/val=0.5261593818664551
# Accuracy/train=99.7         Loss/train=0.3434594330191612
# this is the iters: 13000
# Loss/train= 0.35847712
# Accuracy/val=87.1         Loss/val=0.5142435637116433
# Accuracy/train=99.5         Loss/train=0.34761966407299044
# this is the iters: 13100
# Loss/train= 0.34185547
# Accuracy/val=85.2         Loss/val=0.5249006390571594
# Accuracy/train=99.9         Loss/train=0.3420918980240822
# this is the iters: 13200
# Loss/train= 0.3692163
# Accuracy/val=87.8         Loss/val=0.48645601004362105
# Accuracy/train=99.5         Loss/train=0.34481952130794524
# this is the iters: 13300
# Loss/train= 0.3432513
# Accuracy/val=85.2         Loss/val=0.5196686887741089
# Accuracy/train=99.6         Loss/train=0.3458236119151115
# this is the iters: 13400
# Loss/train= 0.33750224
# Accuracy/val=89.6         Loss/val=0.48446883767843246
# Accuracy/train=99.9         Loss/train=0.3422212755680084
# this is the iters: 13500
# Loss/train= 0.34524176
# Accuracy/val=78.9         Loss/val=0.5569339683651924
# Accuracy/train=99.4         Loss/train=0.35339426159858706
# this is the iters: 13600
# Loss/train= 0.36739856
# Accuracy/val=84.6         Loss/val=0.5174154159426689
# Accuracy/train=99.6         Loss/train=0.3421821084618568
# this is the iters: 13700
# Loss/train= 0.33059463
# Accuracy/val=83.8         Loss/val=0.5278629863262176
# Accuracy/train=99.6         Loss/train=0.3438202029466629
# this is the iters: 13800
# Loss/train= 0.35451445
# Accuracy/val=84.0         Loss/val=0.5147205683588981
# Accuracy/train=99.3         Loss/train=0.3487023618817329
# this is the iters: 13900
# Loss/train= 0.3336421
# Accuracy/val=89.1         Loss/val=0.4810775181651115
# Accuracy/train=99.8         Loss/train=0.3425041350722313
# this is the iters: 14000
# Loss/train= 0.34543964
# Accuracy/val=84.1         Loss/val=0.527639374434948
# Accuracy/train=99.9         Loss/train=0.34366377830505374
# this is the iters: 14100
# Loss/train= 0.34320703
# Accuracy/val=82.6         Loss/val=0.5387125366926193
# Accuracy/train=100.0         Loss/train=0.339130842089653
# this is the iters: 14200
# Loss/train= 0.33608243
# Accuracy/val=88.5         Loss/val=0.4959265312552452
# Accuracy/train=99.8         Loss/train=0.33986391603946686
# this is the iters: 14300
# Loss/train= 0.3722404
# Accuracy/val=82.1         Loss/val=0.5376870203018188
# Accuracy/train=99.9         Loss/train=0.3427903401851654
# this is the iters: 14400
# Loss/train= 0.34525216
# Accuracy/val=84.7         Loss/val=0.5279924845695496
# Accuracy/train=99.7         Loss/train=0.3413113096356392
# this is the iters: 14500
# Loss/train= 0.35677794
# Accuracy/val=85.1         Loss/val=0.5206093418598176
# Accuracy/train=99.6         Loss/train=0.34333662152290345
# this is the iters: 14600
# Loss/train= 0.3335894
# Accuracy/val=89.8         Loss/val=0.48497207403182985
# Accuracy/train=99.9         Loss/train=0.3464083889126778
# this is the iters: 14700
# Loss/train= 0.33681834
# Accuracy/val=90.1         Loss/val=0.4752109068632126
# Accuracy/train=100.0         Loss/train=0.3408794808387756
# this is the iters: 14800
# Loss/train= 0.33372593
# Accuracy/val=90.1         Loss/val=0.4920382472872734
# Accuracy/train=99.7         Loss/train=0.34374078005552294
# this is the iters: 14900
# Loss/train= 0.33402023
# Accuracy/val=86.7         Loss/val=0.5033065661787987
# Accuracy/train=99.9         Loss/train=0.34236772030591966
# this is the iters: 15000
# Loss/train= 0.33238792
# Accuracy/val=90.9         Loss/val=0.47530987054109575
# Accuracy/train=99.7         Loss/train=0.3403575748205185
# this is the iters: 15100
# Loss/train= 0.33774462
# Accuracy/val=91.4         Loss/val=0.47724142849445345
# Accuracy/train=99.8         Loss/train=0.33984667420387266
# this is the iters: 15200
# Loss/train= 0.33902323
# Accuracy/val=90.0         Loss/val=0.49027143746614454
# Accuracy/train=99.6         Loss/train=0.34327701598405835
# this is the iters: 15300
# Loss/train= 0.35309604
# Accuracy/val=92.3         Loss/val=0.45680276691913607
# Accuracy/train=99.9         Loss/train=0.34030943006277087
# this is the iters: 15400
# Loss/train= 0.33042523
# Accuracy/val=91.4         Loss/val=0.4812510097026825
# Accuracy/train=99.8         Loss/train=0.3397094002366066
# this is the iters: 15500
# Loss/train= 0.3434695
# Accuracy/val=88.6         Loss/val=0.49278866171836855
# Accuracy/train=99.9         Loss/train=0.3423515483736992
# this is the iters: 15600
# Loss/train= 0.33995256
# Accuracy/val=89.6         Loss/val=0.47532080352306366
# Accuracy/train=99.8         Loss/train=0.34027100920677184
# this is the iters: 15700
# Loss/train= 0.3633685
# Accuracy/val=89.2         Loss/val=0.4730832180380821
# Accuracy/train=100.0         Loss/train=0.3392664912343025
# this is the iters: 15800
# Loss/train= 0.3357441
# Accuracy/val=87.2         Loss/val=0.4989590525627136
# Accuracy/train=99.7         Loss/train=0.341397185921669
# this is the iters: 15900
# Loss/train= 0.32905832
# Accuracy/val=87.2         Loss/val=0.500364146232605
# Accuracy/train=100.0         Loss/train=0.3384551206231117
# this is the iters: 16000
# Loss/train= 0.3555778
# Accuracy/val=77.1         Loss/val=0.5761527588963509
# Accuracy/train=99.9         Loss/train=0.3408783957362175
# this is the iters: 16100
# Loss/train= 0.33143798
# Accuracy/val=88.0         Loss/val=0.5034237232804298
# Accuracy/train=99.6         Loss/train=0.3432285764813423
# this is the iters: 16200
# Loss/train= 0.35146683
# Accuracy/val=89.9         Loss/val=0.4727363076806068
# Accuracy/train=99.8         Loss/train=0.34099612534046175
# this is the iters: 16300
# Loss/train= 0.3355485
# Accuracy/val=90.0         Loss/val=0.4758482399582863
# Accuracy/train=99.7         Loss/train=0.34118861198425293
# this is the iters: 16400
# Loss/train= 0.33736673
# Accuracy/val=86.7         Loss/val=0.5169581055641175
# Accuracy/train=99.5         Loss/train=0.34398913383483887
# this is the iters: 16500
# Loss/train= 0.33708474
# Accuracy/val=82.3         Loss/val=0.5198566710948944
# Accuracy/train=99.9         Loss/train=0.34233129262924195
# this is the iters: 16600
# Loss/train= 0.33144054
# Accuracy/val=90.3         Loss/val=0.47308635294437407
# Accuracy/train=99.8         Loss/train=0.3382412025332451
# this is the iters: 16700
# Loss/train= 0.3316474
# Accuracy/val=87.6         Loss/val=0.5033508828282356
# Accuracy/train=99.8         Loss/train=0.339685737490654
# this is the iters: 16800
# Loss/train= 0.33583626
# Accuracy/val=84.4         Loss/val=0.5115302556753158
# Accuracy/train=100.0         Loss/train=0.33771606534719467
# this is the iters: 16900
# Loss/train= 0.33775267
# Accuracy/val=89.3         Loss/val=0.4957995781302452
# Accuracy/train=99.8         Loss/train=0.3413261860609055
# this is the iters: 17000
# Loss/train= 0.33630902
# Accuracy/val=85.0         Loss/val=0.5165988337993622
# Accuracy/train=100.0         Loss/train=0.33671070605516434
# this is the iters: 17100
# Loss/train= 0.3470371
# Accuracy/val=85.4         Loss/val=0.5031294560432434
# Accuracy/train=100.0         Loss/train=0.3384147056937218
# this is the iters: 17200
# Loss/train= 0.34128705
# Accuracy/val=76.1         Loss/val=0.5400240939855575
# Accuracy/train=100.0         Loss/train=0.3438049057126045
# this is the iters: 17300
# Loss/train= 0.3448758
# Accuracy/val=91.4         Loss/val=0.45753335535526274
# Accuracy/train=99.9         Loss/train=0.33907642841339114
# this is the iters: 17400
# Loss/train= 0.3405807
# Accuracy/val=89.0         Loss/val=0.5009383615851403
# Accuracy/train=99.8         Loss/train=0.33896631866693494
# this is the iters: 17500
# Loss/train= 0.3343349
# Accuracy/val=86.0         Loss/val=0.505352816581726
# Accuracy/train=100.0         Loss/train=0.33692063361406327
# this is the iters: 17600
# Loss/train= 0.3349574
# Accuracy/val=89.7         Loss/val=0.4853682520985603
# Accuracy/train=100.0         Loss/train=0.33866761952638624
# this is the iters: 17700
# Loss/train= 0.34158778
# Accuracy/val=86.8         Loss/val=0.494777567088604
# Accuracy/train=99.8         Loss/train=0.33936652570962905
# this is the iters: 17800
# Loss/train= 0.37313184
# Accuracy/val=86.6         Loss/val=0.49136426001787187
# Accuracy/train=99.8         Loss/train=0.3376944640278816
# this is the iters: 17900
# Loss/train= 0.3399818
# Accuracy/val=88.2         Loss/val=0.5122486311197281
# Accuracy/train=100.0         Loss/train=0.34112867414951326
# this is the iters: 18000
# Loss/train= 0.3738054
# Accuracy/val=77.9         Loss/val=0.5578456291556358
# Accuracy/train=99.7         Loss/train=0.3414174249768257
# this is the iters: 18100
# Loss/train= 0.33454773
# Accuracy/val=86.2         Loss/val=0.49407391250133514
# Accuracy/train=99.9         Loss/train=0.33826110780239105
# this is the iters: 18200
# Loss/train= 0.32850438
# Accuracy/val=92.9         Loss/val=0.4528963777422905
# Accuracy/train=99.9         Loss/train=0.33681635051965714
# this is the iters: 18300
# Loss/train= 0.33538768
# Accuracy/val=90.6         Loss/val=0.4663592913746834
# Accuracy/train=99.9         Loss/train=0.33773289173841475
# this is the iters: 18400
# Loss/train= 0.3477128
# Accuracy/val=90.1         Loss/val=0.4658430179953575
# Accuracy/train=99.9         Loss/train=0.3384679493308067
# this is the iters: 18500
# Loss/train= 0.34356245
# Accuracy/val=89.0         Loss/val=0.4692259430885315
# Accuracy/train=100.0         Loss/train=0.33642068296670913
# this is the iters: 18600
# Loss/train= 0.35305044
# Accuracy/val=90.5         Loss/val=0.46610591769218446
# Accuracy/train=99.8         Loss/train=0.3397257462143898
# this is the iters: 18700
# Loss/train= 0.34339878
# Accuracy/val=90.7         Loss/val=0.4711158975958824
# Accuracy/train=100.0         Loss/train=0.33731994092464446
# this is the iters: 18800
# Loss/train= 0.33003905
# Accuracy/val=90.0         Loss/val=0.46227712363004686
# Accuracy/train=99.9         Loss/train=0.3359643590450287
# this is the iters: 18900
# Loss/train= 0.33083948
# Accuracy/val=88.3         Loss/val=0.4838064697384834
# Accuracy/train=99.9         Loss/train=0.34001784414052966
# this is the iters: 19000
# Loss/train= 0.3308495
# Accuracy/val=88.0         Loss/val=0.48415541410446167
# Accuracy/train=100.0         Loss/train=0.3403064700961113
# this is the iters: 19100
# Loss/train= 0.33229586
# Accuracy/val=89.0         Loss/val=0.4912914851307869
# Accuracy/train=100.0         Loss/train=0.33928353786468507
# this is the iters: 19200
# Loss/train= 0.33580765
# Accuracy/val=89.3         Loss/val=0.49196263164281845
# Accuracy/train=99.9         Loss/train=0.3380786430835724
# this is the iters: 19300
# Loss/train= 0.34272316
# Accuracy/val=87.3         Loss/val=0.49714886635541916
# Accuracy/train=99.9         Loss/train=0.3386318919062614
# this is the iters: 19400
# Loss/train= 0.33081692
# Accuracy/val=90.9         Loss/val=0.4564772662520409
# Accuracy/train=100.0         Loss/train=0.337180438041687
# this is the iters: 19500
# Loss/train= 0.32968223
# Accuracy/val=87.9         Loss/val=0.48290200233459474
# Accuracy/train=99.9         Loss/train=0.33836889535188674
# this is the iters: 19600
# Loss/train= 0.35209015
# Accuracy/val=90.1         Loss/val=0.47585031628608704
# Accuracy/train=99.8         Loss/train=0.3435287830233574
# this is the iters: 19700
# Loss/train= 0.33445233
# Accuracy/val=89.3         Loss/val=0.48109501898288726
# Accuracy/train=99.9         Loss/train=0.33744779497385025
# this is the iters: 19800
# Loss/train= 0.3358801
# Accuracy/val=89.6         Loss/val=0.4857119074463844
# Accuracy/train=100.0         Loss/train=0.3353249749541283
# this is the iters: 19900
# Loss/train= 0.33553025
# Accuracy/val=88.0         Loss/val=0.4934080398082733
# Accuracy/train=99.9         Loss/train=0.33832998275756837
# this is the iters: 20000
# Loss/train= 0.35657486
# Accuracy/val=89.2         Loss/val=0.48935958355665204
# Accuracy/train=99.9         Loss/train=0.33764863163232806
# this is the iters: 20100
# Loss/train= 0.3397383
# Accuracy/val=72.8         Loss/val=0.5843505606055259
# Accuracy/train=100.0         Loss/train=0.34185210555791856
# this is the iters: 20200
# Loss/train= 0.33400318
# Accuracy/val=86.2         Loss/val=0.4964147946238518
# Accuracy/train=100.0         Loss/train=0.3382798907160759
# this is the iters: 20300
# Loss/train= 0.32940936
# Accuracy/val=88.4         Loss/val=0.4844342860579491
# Accuracy/train=99.9         Loss/train=0.33536761164665224
# this is the iters: 20400
# Loss/train= 0.32765147
# Accuracy/val=86.3         Loss/val=0.503518902361393
# Accuracy/train=100.0         Loss/train=0.33617334723472597
# this is the iters: 20500
# Loss/train= 0.33511606
# Accuracy/val=86.0         Loss/val=0.4862089502811432
# Accuracy/train=99.8         Loss/train=0.3388706374168396
# this is the iters: 20600
# Loss/train= 0.33439857
# Accuracy/val=89.5         Loss/val=0.4804764559864998
# Accuracy/train=100.0         Loss/train=0.33386867970228196
# this is the iters: 20700
# Loss/train= 0.33641672
# Accuracy/val=89.3         Loss/val=0.4807830169796944
# Accuracy/train=100.0         Loss/train=0.3357162195444107
# this is the iters: 20800
# Loss/train= 0.34874237
# Accuracy/val=90.1         Loss/val=0.47300118893384935
# Accuracy/train=100.0         Loss/train=0.33653472691774367
# this is the iters: 20900
# Loss/train= 0.33979478
# Accuracy/val=91.1         Loss/val=0.4838999319076538
# Accuracy/train=99.9         Loss/train=0.3363330802321434
# this is the iters: 21000
# Loss/train= 0.33390808
# Accuracy/val=93.3         Loss/val=0.4288229379057884
# Accuracy/train=100.0         Loss/train=0.3356471562385559
# this is the iters: 21100
# Loss/train= 0.33679116
# Accuracy/val=87.9         Loss/val=0.49127377331256866
# Accuracy/train=99.9         Loss/train=0.3357516238093376
# this is the iters: 21200
# Loss/train= 0.33693084
# Accuracy/val=89.7         Loss/val=0.47861752808094027
# Accuracy/train=100.0         Loss/train=0.33566066741943357
# this is the iters: 21300
# Loss/train= 0.33080804
# Accuracy/val=88.7         Loss/val=0.4820330259203911
# Accuracy/train=99.9         Loss/train=0.33525972843170165
# this is the iters: 21400
# Loss/train= 0.33386716
# Accuracy/val=85.2         Loss/val=0.5053395482897759
# Accuracy/train=99.9         Loss/train=0.33604646801948546
# this is the iters: 21500
# Loss/train= 0.33462897
# Accuracy/val=91.4         Loss/val=0.46747161746025084
# Accuracy/train=99.8         Loss/train=0.33900919169187543
# this is the iters: 21600
# Loss/train= 0.32918024
# Accuracy/val=89.1         Loss/val=0.48336620002985
# Accuracy/train=99.7         Loss/train=0.3379623368382454
# this is the iters: 21700
# Loss/train= 0.3269163
# Accuracy/val=92.1         Loss/val=0.4530462267994881
# Accuracy/train=100.0         Loss/train=0.33702138930559156
# this is the iters: 21800
# Loss/train= 0.33814913
# Accuracy/val=90.5         Loss/val=0.47630752354860306
# Accuracy/train=100.0         Loss/train=0.3342572391033173
# this is the iters: 21900
# Loss/train= 0.35555482
# Accuracy/val=89.9         Loss/val=0.48793995678424834
# Accuracy/train=100.0         Loss/train=0.3363055345416069
# this is the iters: 22000
# Loss/train= 0.35365897
# Accuracy/val=87.8         Loss/val=0.48502990156412124
# Accuracy/train=99.9         Loss/train=0.3354392722249031
# this is the iters: 22100
# Loss/train= 0.34395272
# Accuracy/val=89.8         Loss/val=0.48752519726753235
# Accuracy/train=99.7         Loss/train=0.33637026220560073
# this is the iters: 22200
# Loss/train= 0.3576688
# Accuracy/val=90.4         Loss/val=0.4563780230283737
# Accuracy/train=99.9         Loss/train=0.3373173102736473
# this is the iters: 22300
# Loss/train= 0.33021426
# Accuracy/val=87.3         Loss/val=0.498613286614418
# Accuracy/train=100.0         Loss/train=0.33703478962183
# this is the iters: 22400
# Loss/train= 0.33262905
# Accuracy/val=90.0         Loss/val=0.4870447009801865
# Accuracy/train=100.0         Loss/train=0.3362081617116928
# this is the iters: 22500
# Loss/train= 0.33472303
# Accuracy/val=89.8         Loss/val=0.47805474102497103
# Accuracy/train=100.0         Loss/train=0.3334670168161392
# this is the iters: 22600
# Loss/train= 0.33471504
# Accuracy/val=90.1         Loss/val=0.4710784292221069
# Accuracy/train=100.0         Loss/train=0.3352511876821518
# this is the iters: 22700
# Loss/train= 0.34832087
# Accuracy/val=90.2         Loss/val=0.45869803726673125
# Accuracy/train=100.0         Loss/train=0.33752799808979034
# this is the iters: 22800
# Loss/train= 0.34155923
# Accuracy/val=87.5         Loss/val=0.4842176952958107
# Accuracy/train=100.0         Loss/train=0.3389882662892342
# this is the iters: 22900
# Loss/train= 0.3342309
# Accuracy/val=88.9         Loss/val=0.4730651441216469
# Accuracy/train=100.0         Loss/train=0.33405541867017746
# this is the iters: 23000
# Loss/train= 0.33442417
# Accuracy/val=88.3         Loss/val=0.4762642139196396
# Accuracy/train=100.0         Loss/train=0.334310901761055
# this is the iters: 23100
# Loss/train= 0.33141005
# Accuracy/val=88.8         Loss/val=0.48646468937397
# Accuracy/train=100.0         Loss/train=0.334846730530262
# this is the iters: 23200
# Loss/train= 0.33020446
# Accuracy/val=90.4         Loss/val=0.4712237104773521
# Accuracy/train=100.0         Loss/train=0.3338852718472481
# this is the iters: 23300
# Loss/train= 0.33018085
# Accuracy/val=86.3         Loss/val=0.4998191061615944
# Accuracy/train=100.0         Loss/train=0.33546317130327225
# this is the iters: 23400
# Loss/train= 0.33351246
# Accuracy/val=89.7         Loss/val=0.4718288105726242
# Accuracy/train=100.0         Loss/train=0.33499895632266996
# this is the iters: 23500
# Loss/train= 0.32715818
# Accuracy/val=91.3         Loss/val=0.46474198639392855
# Accuracy/train=100.0         Loss/train=0.3341917926073074
# this is the iters: 23600
# Loss/train= 0.3367195
# Accuracy/val=90.2         Loss/val=0.4883201515674591
# Accuracy/train=100.0         Loss/train=0.33574733227491377
# this is the iters: 23700
# Loss/train= 0.33709702
# Accuracy/val=90.6         Loss/val=0.46542826741933824
# Accuracy/train=100.0         Loss/train=0.33386055141687393
# this is the iters: 23800
# Loss/train= 0.342299
# Accuracy/val=84.6         Loss/val=0.48990860491991045
# Accuracy/train=100.0         Loss/train=0.3397339898347855
# this is the iters: 23900
# Loss/train= 0.35752478
# Accuracy/val=90.5         Loss/val=0.47095035403966906
# Accuracy/train=100.0         Loss/train=0.3335505595803261
# this is the iters: 24000
# Loss/train= 0.33091038
# Accuracy/val=90.2         Loss/val=0.46822397530078885
# Accuracy/train=100.0         Loss/train=0.3344523882865906
# this is the iters: 24100
# Loss/train= 0.32896924
# Accuracy/val=82.3         Loss/val=0.5148450544476509
# Accuracy/train=100.0         Loss/train=0.33417340844869614
# this is the iters: 24200
# Loss/train= 0.3308113
# Accuracy/val=88.3         Loss/val=0.5001476600766182
# Accuracy/train=100.0         Loss/train=0.3339509987831116
# this is the iters: 24300
# Loss/train= 0.33154765
# Accuracy/val=88.8         Loss/val=0.48001263827085494
# Accuracy/train=99.9         Loss/train=0.3334444811940193
# this is the iters: 24400
# Loss/train= 0.32898414
# Accuracy/val=90.4         Loss/val=0.4749388355016708
# Accuracy/train=100.0         Loss/train=0.3340519520640373
# this is the iters: 24500
# Loss/train= 0.32975274
# Accuracy/val=90.7         Loss/val=0.4721447557210922
# Accuracy/train=100.0         Loss/train=0.33294959366321564
# this is the iters: 24600
# Loss/train= 0.3341643
# Accuracy/val=91.5         Loss/val=0.46134616911411286
# Accuracy/train=100.0         Loss/train=0.3351133242249489
# this is the iters: 24700
# Loss/train= 0.3414808
# Accuracy/val=88.9         Loss/val=0.47696915924549105
# Accuracy/train=100.0         Loss/train=0.33461255341768265
# this is the iters: 24800
# Loss/train= 0.33303672
# Accuracy/val=87.3         Loss/val=0.4700873792171478
# Accuracy/train=100.0         Loss/train=0.33320426046848295
# this is the iters: 24900
# Loss/train= 0.34264526
# Accuracy/val=88.3         Loss/val=0.49766950935125354
# Accuracy/train=99.8         Loss/train=0.3368571701645851
# this is the iters: 25000
# Loss/train= 0.33390447
# Accuracy/val=86.0         Loss/val=0.49528124690055847
# Accuracy/train=100.0         Loss/train=0.3350705289840698
# this is the iters: 25100
# Loss/train= 0.33651456
# Accuracy/val=92.4         Loss/val=0.4580707773566246
# Accuracy/train=99.8         Loss/train=0.3350513714551926
# this is the iters: 25200
# Loss/train= 0.3322796
# Accuracy/val=85.6         Loss/val=0.5095400673151016
# Accuracy/train=100.0         Loss/train=0.33354345500469207
# this is the iters: 25300
# Loss/train= 0.3324177
# Accuracy/val=88.3         Loss/val=0.4821961468458176
# Accuracy/train=100.0         Loss/train=0.33366154789924624
# this is the iters: 25400
# Loss/train= 0.33549473
# Accuracy/val=85.3         Loss/val=0.49035644680261614
# Accuracy/train=99.9         Loss/train=0.33915757030248644
# this is the iters: 25500
# Loss/train= 0.34454235
# Accuracy/val=87.1         Loss/val=0.4795296096801758
# Accuracy/train=99.9         Loss/train=0.3344572791457176
# this is the iters: 25600
# Loss/train= 0.33095536
# Accuracy/val=87.0         Loss/val=0.4960392835736275
# Accuracy/train=99.9         Loss/train=0.3339210832118988
# this is the iters: 25700
# Loss/train= 0.32895717
# Accuracy/val=89.6         Loss/val=0.47287692248821256
# Accuracy/train=99.8         Loss/train=0.33616765707731244
# this is the iters: 25800
# Loss/train= 0.33156282
# Accuracy/val=88.1         Loss/val=0.48886099994182586
# Accuracy/train=100.0         Loss/train=0.33382247895002365
# this is the iters: 25900
# Loss/train= 0.32897457
# Accuracy/val=92.2         Loss/val=0.46524710148572923
# Accuracy/train=99.8         Loss/train=0.33464703142642976
# this is the iters: 26000
# Loss/train= 0.33257294
# Accuracy/val=88.3         Loss/val=0.45719275712966917
# Accuracy/train=100.0         Loss/train=0.3346865752339363
# this is the iters: 26100
# Loss/train= 0.3307495
# Accuracy/val=87.5         Loss/val=0.48647522866725923
# Accuracy/train=100.0         Loss/train=0.333534442782402
# this is the iters: 26200
# Loss/train= 0.3312091
# Accuracy/val=88.6         Loss/val=0.47747835516929626
# Accuracy/train=99.8         Loss/train=0.3356599587202072
# this is the iters: 26300
# Loss/train= 0.3301777
# Accuracy/val=90.7         Loss/val=0.4753780162334442
# Accuracy/train=100.0         Loss/train=0.33554566383361817
# this is the iters: 26400
# Loss/train= 0.3303461
# Accuracy/val=90.4         Loss/val=0.47681007474660875
# Accuracy/train=100.0         Loss/train=0.3338786029815674
# this is the iters: 26500
# Loss/train= 0.358984
# Accuracy/val=85.6         Loss/val=0.4819984829425812
# Accuracy/train=100.0         Loss/train=0.3360461360216141
# this is the iters: 26600
# Loss/train= 0.33236653
# Accuracy/val=89.6         Loss/val=0.47048074632883075
# Accuracy/train=100.0         Loss/train=0.33266367942094804
# this is the iters: 26700
# Loss/train= 0.3286796
# Accuracy/val=90.4         Loss/val=0.47704130738973616
# Accuracy/train=100.0         Loss/train=0.3332958951592445
# this is the iters: 26800
# Loss/train= 0.33044884
# Accuracy/val=88.7         Loss/val=0.4833551800251007
# Accuracy/train=100.0         Loss/train=0.3337751859426498
# this is the iters: 26900
# Loss/train= 0.3383363
# Accuracy/val=90.6         Loss/val=0.4608839070796967
# Accuracy/train=100.0         Loss/train=0.331688714325428
# this is the iters: 27000
# Loss/train= 0.33165702
# Accuracy/val=87.4         Loss/val=0.4845830222964287
# Accuracy/train=100.0         Loss/train=0.33364039808511736
# this is the iters: 27100
# Loss/train= 0.33392477
# Accuracy/val=89.0         Loss/val=0.47185114443302156
# Accuracy/train=100.0         Loss/train=0.3323982357978821
# this is the iters: 27200
# Loss/train= 0.3338448
# Accuracy/val=91.3         Loss/val=0.4663531360030174
# Accuracy/train=100.0         Loss/train=0.33300777196884157
# this is the iters: 27300
# Loss/train= 0.32839832
# Accuracy/val=91.2         Loss/val=0.46540347933769227
# Accuracy/train=100.0         Loss/train=0.3355263662338257
# this is the iters: 27400
# Loss/train= 0.33516502
# Accuracy/val=90.9         Loss/val=0.46040464997291564
# Accuracy/train=99.9         Loss/train=0.33324699133634567
# this is the iters: 27500
# Loss/train= 0.3300961
# Accuracy/val=88.2         Loss/val=0.4737792131304741
# Accuracy/train=100.0         Loss/train=0.3334716695547104
# this is the iters: 27600
# Loss/train= 0.3400416
# Accuracy/val=91.2         Loss/val=0.4642048302292824
# Accuracy/train=99.9         Loss/train=0.335674766600132
# this is the iters: 27700
# Loss/train= 0.33133307
# Accuracy/val=88.3         Loss/val=0.4754737517237663
# Accuracy/train=100.0         Loss/train=0.33250259757041933
# this is the iters: 27800
# Loss/train= 0.3295904
# Accuracy/val=88.9         Loss/val=0.47231996595859527
# Accuracy/train=100.0         Loss/train=0.3338980343937874
# this is the iters: 27900
# Loss/train= 0.3301649
# Accuracy/val=90.2         Loss/val=0.4732387110590935
# Accuracy/train=100.0         Loss/train=0.33252271711826326
# this is the iters: 28000
# Loss/train= 0.33046767
# Accuracy/val=90.1         Loss/val=0.4720190495252609
# Accuracy/train=100.0         Loss/train=0.3332178398966789
# this is the iters: 28100
# Loss/train= 0.33518368
# Accuracy/val=84.6         Loss/val=0.5055477905273438
# Accuracy/train=100.0         Loss/train=0.33426574409008025
# this is the iters: 28200
# Loss/train= 0.34071732
# Accuracy/val=91.3         Loss/val=0.4608609372377396
# Accuracy/train=100.0         Loss/train=0.33236071467399597
# this is the iters: 28300
# Loss/train= 0.3412054
# Accuracy/val=86.7         Loss/val=0.490545708835125
# Accuracy/train=100.0         Loss/train=0.3333262041211128
# this is the iters: 28400
# Loss/train= 0.34023356
# Accuracy/val=91.4         Loss/val=0.461547386944294
# Accuracy/train=100.0         Loss/train=0.333459897339344
# this is the iters: 28500
# Loss/train= 0.3309035
# Accuracy/val=86.4         Loss/val=0.483773775100708
# Accuracy/train=100.0         Loss/train=0.3327876889705658
# this is the iters: 28600
# Loss/train= 0.33246055
# Accuracy/val=89.5         Loss/val=0.4620156902074814
# Accuracy/train=100.0         Loss/train=0.3331074523925781
# this is the iters: 28700
# Loss/train= 0.33404016
# Accuracy/val=91.0         Loss/val=0.4496864974498749
# Accuracy/train=99.9         Loss/train=0.332776198387146
# this is the iters: 28800
# Loss/train= 0.33453953
# Accuracy/val=90.6         Loss/val=0.4742962482571602
# Accuracy/train=100.0         Loss/train=0.3322792237997055
# this is the iters: 28900
# Loss/train= 0.33329058
# Accuracy/val=89.5         Loss/val=0.4649998182058334
# Accuracy/train=100.0         Loss/train=0.3328013351559639
# this is the iters: 29000
# Loss/train= 0.33277044
# Accuracy/val=89.6         Loss/val=0.4836063069105148
# Accuracy/train=100.0         Loss/train=0.3320394504070282
# this is the iters: 29100
# Loss/train= 0.35331908
# Accuracy/val=89.5         Loss/val=0.47723635017871857
# Accuracy/train=100.0         Loss/train=0.33285522282123564
# this is the iters: 29200
# Loss/train= 0.33010536
# Accuracy/val=92.0         Loss/val=0.4576971223950386
# Accuracy/train=100.0         Loss/train=0.3311363339424133
# this is the iters: 29300
# Loss/train= 0.33360216
# Accuracy/val=89.0         Loss/val=0.46615411818027497
# Accuracy/train=100.0         Loss/train=0.3334210342168808
# this is the iters: 29400
# Loss/train= 0.33168942
# Accuracy/val=93.2         Loss/val=0.43665896624326705
# Accuracy/train=100.0         Loss/train=0.3319151896238327
# this is the iters: 29500
# Loss/train= 0.33601567
# Accuracy/val=89.4         Loss/val=0.46474228709936144
# Accuracy/train=100.0         Loss/train=0.3315992847084999
# this is the iters: 29600
# Loss/train= 0.3309144
# Accuracy/val=92.4         Loss/val=0.4532256034016609
# Accuracy/train=100.0         Loss/train=0.3315324792265892
# this is the iters: 29700
# Loss/train= 0.33175373
# Accuracy/val=88.2         Loss/val=0.47455329179763794
# Accuracy/train=100.0         Loss/train=0.3318233296275139
# this is the iters: 29800
# Loss/train= 0.3317256
# Accuracy/val=88.2         Loss/val=0.4884149432182312
# Accuracy/train=100.0         Loss/train=0.3316865757107735
# this is the iters: 29900
# Loss/train= 0.3318379
# Accuracy/val=89.7         Loss/val=0.46946782141923904
# Accuracy/train=100.0         Loss/train=0.3317871618270874
# this is the iters: 30000
# Loss/train= 0.33514786
# Accuracy/val=82.5         Loss/val=0.5334500488638878
# Accuracy/train=100.0         Loss/train=0.3325165969133377
# this is the iters: 30100
# Loss/train= 0.32795602
# Accuracy/val=91.9         Loss/val=0.4575421616435051
# Accuracy/train=100.0         Loss/train=0.3316913706064224
# this is the iters: 30200
# Loss/train= 0.32949683
# Accuracy/val=90.3         Loss/val=0.4581751999258995
# Accuracy/train=100.0         Loss/train=0.33245917499065397
# this is the iters: 30300
# Loss/train= 0.3331662
# Accuracy/val=86.7         Loss/val=0.4835967993736267
# Accuracy/train=99.9         Loss/train=0.33418230652809144
# this is the iters: 30400
# Loss/train= 0.3311405
# Accuracy/val=89.2         Loss/val=0.47850435703992844
# Accuracy/train=100.0         Loss/train=0.3313521200418472
# this is the iters: 30500
# Loss/train= 0.33301005
# Accuracy/val=92.5         Loss/val=0.45585122317075727
# Accuracy/train=100.0         Loss/train=0.3377545258402824
# this is the iters: 30600
# Loss/train= 0.35536692
# Accuracy/val=90.3         Loss/val=0.4554808270931244
# Accuracy/train=100.0         Loss/train=0.332705449461937
# this is the iters: 30700
# Loss/train= 0.33505982
# Accuracy/val=90.3         Loss/val=0.47479093700647357
# Accuracy/train=100.0         Loss/train=0.3316531455516815
# this is the iters: 30800
# Loss/train= 0.332084
# Accuracy/val=90.3         Loss/val=0.4750475335121155
# Accuracy/train=100.0         Loss/train=0.3320758494734764
# this is the iters: 30900
# Loss/train= 0.32808065
# Accuracy/val=90.1         Loss/val=0.4759898245334625
# Accuracy/train=100.0         Loss/train=0.3315769898891449
# this is the iters: 31000
# Loss/train= 0.32872105
# Accuracy/val=89.6         Loss/val=0.47497223794460297
# Accuracy/train=100.0         Loss/train=0.33270091950893405
# this is the iters: 31100
# Loss/train= 0.3332988
# Accuracy/val=90.3         Loss/val=0.4647584557533264
# Accuracy/train=100.0         Loss/train=0.33128003269433975
# this is the iters: 31200
# Loss/train= 0.33298847
# Accuracy/val=93.2         Loss/val=0.44745511263608934
# Accuracy/train=99.9         Loss/train=0.3343196761608124
# this is the iters: 31300
# Loss/train= 0.33721957
# Accuracy/val=83.6         Loss/val=0.5190344452857971
# Accuracy/train=100.0         Loss/train=0.33387777596712115
# this is the iters: 31400
# Loss/train= 0.32999474
# Accuracy/val=91.6         Loss/val=0.45307658821344376
# Accuracy/train=100.0         Loss/train=0.3317624306678772
# this is the iters: 31500
# Loss/train= 0.32972786
# Accuracy/val=89.7         Loss/val=0.47458539783954623
# Accuracy/train=100.0         Loss/train=0.3316892704367638
# this is the iters: 31600
# Loss/train= 0.32878795
# Accuracy/val=89.2         Loss/val=0.4739269173145294
# Accuracy/train=100.0         Loss/train=0.3309822353720665
# this is the iters: 31700
# Loss/train= 0.32853183
# Accuracy/val=92.7         Loss/val=0.44102520316839217
# Accuracy/train=100.0         Loss/train=0.3319056722521782
# this is the iters: 31800
# Loss/train= 0.32949957
# Accuracy/val=89.7         Loss/val=0.4656858691573143
# Accuracy/train=100.0         Loss/train=0.3320689386129379
# this is the iters: 31900
# Loss/train= 0.3338605
# Accuracy/val=92.6         Loss/val=0.4387187105417252
# Accuracy/train=100.0         Loss/train=0.3324128043651581
# this is the iters: 32000
# Loss/train= 0.33169767
# Accuracy/val=84.2         Loss/val=0.5109796807169914
# Accuracy/train=99.9         Loss/train=0.33484539538621905
# this is the iters: 32100
# Loss/train= 0.3363687
# Accuracy/val=86.5         Loss/val=0.4974952179193497
# Accuracy/train=100.0         Loss/train=0.3310365927219391
# this is the iters: 32200
# Loss/train= 0.3339289
# Accuracy/val=85.7         Loss/val=0.5008743304014206
# Accuracy/train=99.9         Loss/train=0.3327939280867577
# this is the iters: 32300
# Loss/train= 0.32978702
# Accuracy/val=87.7         Loss/val=0.47346629172563554
# Accuracy/train=100.0         Loss/train=0.33256903260946274
# this is the iters: 32400
# Loss/train= 0.3317258
# Accuracy/val=87.8         Loss/val=0.49097456902265546
# Accuracy/train=100.0         Loss/train=0.3321411681175232
# this is the iters: 32500
# Loss/train= 0.3342238
# Accuracy/val=86.7         Loss/val=0.4898640009760857
# Accuracy/train=100.0         Loss/train=0.33226004034280776
# this is the iters: 32600
# Loss/train= 0.3328676
# Accuracy/val=88.9         Loss/val=0.4688660180568695
# Accuracy/train=100.0         Loss/train=0.33189161866903305
# this is the iters: 32700
# Loss/train= 0.3301586
# Accuracy/val=87.6         Loss/val=0.4704590919613838
# Accuracy/train=100.0         Loss/train=0.3318001773953438
# this is the iters: 32800
# Loss/train= 0.3380276
# Accuracy/val=89.0         Loss/val=0.4742898768186569
# Accuracy/train=100.0         Loss/train=0.33234375655651094
# this is the iters: 32900
# Loss/train= 0.3304181
# Accuracy/val=85.8         Loss/val=0.5006027093529701
# Accuracy/train=100.0         Loss/train=0.33283560782670973
# this is the iters: 33000
# Loss/train= 0.32725072
# Accuracy/val=88.0         Loss/val=0.4770821648836136
# Accuracy/train=100.0         Loss/train=0.331093861758709
# this is the iters: 33100
# Loss/train= 0.3394737
# Accuracy/val=90.1         Loss/val=0.4709499603509903
# Accuracy/train=100.0         Loss/train=0.3343753343820572
# this is the iters: 33200
# Loss/train= 0.32924673
# Accuracy/val=90.4         Loss/val=0.4642091962695122
# Accuracy/train=100.0         Loss/train=0.3317114496231079
# this is the iters: 33300
# Loss/train= 0.33123335
# Accuracy/val=89.4         Loss/val=0.4653883188962936
# Accuracy/train=100.0         Loss/train=0.33174591094255446
# this is the iters: 33400
# Loss/train= 0.33035323
# Accuracy/val=91.3         Loss/val=0.475991458594799
# Accuracy/train=100.0         Loss/train=0.33186460673809054
# this is the iters: 33500
# Loss/train= 0.3276672
# Accuracy/val=88.2         Loss/val=0.4853062051534653
# Accuracy/train=100.0         Loss/train=0.33044025391340254
# this is the iters: 33600
# Loss/train= 0.33346915
# Accuracy/val=91.3         Loss/val=0.4603953018784523
# Accuracy/train=99.9         Loss/train=0.33167856842279436
# this is the iters: 33700
# Loss/train= 0.32985097
# Accuracy/val=90.5         Loss/val=0.4582667779922485
# Accuracy/train=100.0         Loss/train=0.33366995841264724
# this is the iters: 33800
# Loss/train= 0.3289033
# Accuracy/val=87.4         Loss/val=0.48785099625587464
# Accuracy/train=100.0         Loss/train=0.3310743051767349
# this is the iters: 33900
# Loss/train= 0.33007345
# Accuracy/val=89.3         Loss/val=0.4520446574687958
# Accuracy/train=100.0         Loss/train=0.33095122009515765
# this is the iters: 34000
# Loss/train= 0.3296435
# Accuracy/val=91.7         Loss/val=0.4567995858192444
# Accuracy/train=100.0         Loss/train=0.33019719779491424
# this is the iters: 34100
# Loss/train= 0.3278793
# Accuracy/val=83.0         Loss/val=0.5083443319797516
# Accuracy/train=100.0         Loss/train=0.3346007293462753
# this is the iters: 34200
# Loss/train= 0.32967377
# Accuracy/val=88.0         Loss/val=0.4632818204164505
# Accuracy/train=100.0         Loss/train=0.3319742015004158
# this is the iters: 34300
# Loss/train= 0.32923338
# Accuracy/val=87.6         Loss/val=0.4791428312659264
# Accuracy/train=100.0         Loss/train=0.33178669333457944
# this is the iters: 34400
# Loss/train= 0.3287599
# Accuracy/val=91.8         Loss/val=0.455377114713192
# Accuracy/train=100.0         Loss/train=0.3318280303478241
# this is the iters: 34500
# Loss/train= 0.3320969
# Accuracy/val=88.4         Loss/val=0.4639628076553345
# Accuracy/train=100.0         Loss/train=0.3309997469186783
# this is the iters: 34600
# Loss/train= 0.33022833
# Accuracy/val=88.9         Loss/val=0.4576814386248589
# Accuracy/train=100.0         Loss/train=0.330937967300415
# this is the iters: 34700
# Loss/train= 0.33568624
# Accuracy/val=90.3         Loss/val=0.46667249262332916
# Accuracy/train=100.0         Loss/train=0.3323834788799286
# this is the iters: 34800
# Loss/train= 0.33299682
# Accuracy/val=89.5         Loss/val=0.47149300515651704
# Accuracy/train=99.9         Loss/train=0.3314147126674652
# this is the iters: 34900

# %% [markdown]
# ## test

# %%
import torch
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# 文件夹路径
model_dir = os.path.join(result_path, 'checkpoint')

# 获取所有以 '.pth' 结尾的文件
model_files = [f for f in os.listdir(model_dir) if f.endswith('.pth')]

# 存储每个模型的准确率
test_acc = 0

# 遍历每个模型文件
for model_file in model_files:
    model_path = os.path.join(model_dir, model_file)
    # 加载模型
    model.load_state_dict(torch.load(model_path))
    with torch.no_grad():
        # 验证
        iterations = 500
        avg_acc = 0
        all_preds = []
        all_labels = []
        for _ in range(iterations):
            batch_x, batch_y = get_batch(batch_size, split='test')
            cleaned = model(batch_x)
            # 将预测和真实标签添加到列表中
            all_labels.extend(torch.round(batch_y).cpu().numpy())  # 将真实标签四舍五入为离散值
            all_preds.extend(torch.round(cleaned).cpu().numpy())   # 将预测值四舍五入为离散值
            count = 0
            acc = 0
            for num in cleaned:
                if int(torch.round(num)) == int(torch.round(batch_y[count])):
                    acc += 10
                count += 1
            avg_acc += acc
        avg_acc = avg_acc / iterations
        print(f'模型 {model_file} 的测试集准确率：{avg_acc}')
        if avg_acc > test_acc:
            test_acc = avg_acc
            # 将列表转换为整数类型
            all_labels = np.array(all_labels, dtype=int)
            all_preds = np.array(all_preds, dtype=int)
            cm = confusion_matrix(all_labels, all_preds)
            # 绘制混淆矩阵
            plt.figure(figsize=(8, 6))
            sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                        xticklabels=['Class 0', 'Class 1'],
                        yticklabels=['Class 0', 'Class 1'])
            plt.ylabel('True label')
            plt.xlabel('Predicted label')
            plt.title(f'Confusion Matrix for {model_file}')
            # 保存混淆矩阵图像
            test_path = os.path.join(result_path, 'test')
            if not os.path.exists(test_path):
                os.makedirs(test_path)
            plt.savefig(os.path.join(test_path, f'confusion_matrix_{model_file}.png'))
            plt.close()  # 关闭当前图形
            # 计算指标
            TN = cm[0][0]
            FP = cm[0][1]
            FN = cm[1][0]
            TP = cm[1][1]
            Sensitivity = TP / (TP + FN) if (TP + FN) > 0 else 0
            Specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
            Precision = TP / (TP + FP) if (TP + FP) > 0 else 0
            F1 = 2 * (Precision * Sensitivity) / (Precision + Sensitivity) if (Precision + Sensitivity) > 0 else 0
            # 保存最佳模型的结果
            with open(os.path.join(test_path, 'best_test_accuracy2.txt'), 'a') as f:
                f.write(f"模型 {model_file}   Best Accuracy: {test_acc}, ")
                f.write(f"Sensitivity: {Sensitivity}, Specificity: {Specificity}, ")
                f.write(f"Precision: {Precision}, F1 Score: {F1}\n")  # 在同一行输出
# Out:
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_100.pth 的测试集准确率：69.1
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_1000.pth 的测试集准确率：81.64
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_10000.pth 的测试集准确率：99.1
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_10100.pth 的测试集准确率：98.84
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_10200.pth 的测试集准确率：99.58
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_10300.pth 的测试集准确率：99.58
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_10400.pth 的测试集准确率：98.76
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_10500.pth 的测试集准确率：99.58
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_10600.pth 的测试集准确率：99.0
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_10700.pth 的测试集准确率：98.62
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_10800.pth 的测试集准确率：99.46
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_10900.pth 的测试集准确率：99.62
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_1100.pth 的测试集准确率：93.44
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_11000.pth 的测试集准确率：99.06
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_11100.pth 的测试集准确率：99.96
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_11200.pth 的测试集准确率：98.28
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_11300.pth 的测试集准确率：97.74
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_11400.pth 的测试集准确率：98.5
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_11500.pth 的测试集准确率：99.86
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_11600.pth 的测试集准确率：99.08
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_11700.pth 的测试集准确率：99.4
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_11800.pth 的测试集准确率：99.76
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_11900.pth 的测试集准确率：99.66
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_1200.pth 的测试集准确率：93.6
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_12000.pth 的测试集准确率：99.52
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_12100.pth 的测试集准确率：99.64
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_12200.pth 的测试集准确率：99.54
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_12300.pth 的测试集准确率：99.34
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_12400.pth 的测试集准确率：98.84
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_12500.pth 的测试集准确率：98.36
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_12600.pth 的测试集准确率：99.64
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_12700.pth 的测试集准确率：99.78
# C:\Users\20218\AppData\Local\Temp\ipykernel_15996\3744439521.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))

# %%
import torch
import os
import torch
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
# result_path = r'result_tran&valid&test\ptbdb\40\self-onn_FECAM\2025-03-01-15-56-19'
# 文件夹路径
# model_dir = r'result_tran&valid&test\ptbdb\32\self-onn_Fcanet\2025-03-04-17-52-19\checkpoint'
model_dir = os.path.join(result_path, 'checkpoint')
# 获取所有以 '.pth' 结尾的文件
model_files = [f for f in os.listdir(model_dir) if f.endswith('.pth')]

# 存储每个模型的准确率
test_acc = 0
# 遍历每个模型文件
for model_file in model_files:
    model_path = os.path.join(model_dir, model_file)
    
    # 加载模型
    model.load_state_dict(torch.load(model_path))
    
    with torch.no_grad():
        # 验证
        iterations = 500
        avg_acc = 0

        all_preds = []
        all_labels = []

        for _ in range(iterations):
            batch_x, batch_y = get_batch(batch_size, split='test')
            
            cleaned = model(batch_x)


            # 将预测和真实标签添加到列表中
            all_labels.extend(batch_y.cpu().numpy())
            all_preds.extend(torch.round(cleaned).cpu().numpy())

            count = 0
            acc = 0
            for num in cleaned:
                if int(torch.round(num)) == int(torch.round(batch_y[count])):
                    acc += 10
                count += 1
            avg_acc += acc

        avg_acc = avg_acc / iterations
        print(f'模型 {model_file} 的测试集准确率：{avg_acc}')
        if avg_acc > test_acc:
            test_acc = avg_acc
            print("all_labels: ", all_labels)
            print("all_preds: ", all_preds)
            cm = confusion_matrix(all_labels, all_preds)

            # 绘制混淆矩阵
            plt.figure(figsize=(8, 6))
            sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                        xticklabels=['Class 0', 'Class 1'], 
                        yticklabels=['Class 0', 'Class 1'])
            plt.ylabel('True label')
            plt.xlabel('Predicted label')
            plt.title(f'Confusion Matrix for {model_file}')
            
            # 保存混淆矩阵图像
            test_path = os.path.join(result_path, 'test')
            if not os.path.exists(test_path):
                os.makedirs(test_path)
            plt.savefig(os.path.join(test_path, f'confusion_matrix_{model_file}.png'))
            plt.close()  # 关闭当前图形

             # 计算指标
            TN = cm[0][0]
            FP = cm[0][1]
            FN = cm[1][0]
            TP = cm[1][1]

            Sensitivity = TP / (TP + FN) if (TP + FN) > 0 else 0
            Specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
            Precision = TP / (TP + FP) if (TP + FP) > 0 else 0
            F1 = 2 * (Precision * Sensitivity) / (Precision + Sensitivity) if (Precision + Sensitivity) > 0 else 0
            
            # 保存最佳模型的结果
            with open(os.path.join(test_path, 'best_test_accuracy2.txt'), 'a') as f:
                f.write(f"模型 {model_file}   Best Accuracy: {test_acc}, ")
                f.write(f"Sensitivity: {Sensitivity}, Specificity: {Specificity}, ")
                f.write(f"Precision: {Precision}, F1 Score: {F1}\n")  # 在同一行输出
# Out:
# C:\Users\20218\AppData\Local\Temp\ipykernel_12996\2336172583.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型 model_100.pth 的测试集准确率：62.96
# all_labels:  [array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.1], dtype=float32), array([0.9], dtype=float32), array([0.1],  ...
# all_preds:  [array([1.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([1.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([1.], dtype=float32), array([1.], dtype=float32), array([1.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([1.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32), array([0.], ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 56
#      54 print("all_labels: ", all_labels)
#      55 print("all_preds: ", all_preds)
# ---> 56 cm = confusion_matrix(all_labels, all_preds)
#      58 # 绘制混淆矩阵
#      59 plt.figure(figsize=(8, 6))
#
# File d:\minianaconda\envs\pt\lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File d:\minianaconda\envs\pt\lib\site-packages\sklearn\metrics\_classification.py:342, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     247 @validate_params(
#     248     {
#     249         "y_true": ["array-like"],
#    (...)
#     258     y_true, y_pred, *, labels=None, sample_weight=None, normalize=None
#     259 ):
#     260     """Compute confusion matrix to evaluate the accuracy of a classification.
#     261
#     262     By definition a confusion matrix :math:`C` is such that :math:`C_{i, j}`
#    (...)
#     340     (np.int64(0), np.int64(2), np.int64(1), np.int64(1))
#     341     """
# --> 342     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     343     if y_type not in ("binary", "multiclass"):
#     344         raise ValueError("%s is not supported" % y_type)
#
# File d:\minianaconda\envs\pt\lib\site-packages\sklearn\metrics\_classification.py:112, in _check_targets(y_true, y_pred)
#     109     y_type = {"multiclass"}
#     111 if len(y_type) > 1:
# --> 112     raise ValueError(
#     113         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#     114             type_true, type_pred
#     115         )
#     116     )
#     118 # We can't have more than one value on y_type => The set is no more needed
#     119 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of continuous and binary targets

# %%
import os
import torch

test_acc = 0

model_path = r'result_tran&valid&test\ptbdb\42\Self_ONN_fcanet_Adaptive_8\2025-03-26-11-18-40\checkpoint\model_26700.pth'
    
    # 加载模型
model.load_state_dict(torch.load(model_path))
    
with torch.no_grad():
        # 验证
    iterations = 500
    avg_acc = 0

    for _ in range(iterations):
        batch_x, batch_y = get_batch(batch_size, split='test')
            
        cleaned = model(batch_x)

        count = 0
        acc = 0
        for num in cleaned:
            if int(torch.round(num)) == int(torch.round(batch_y[count])):
                acc += 10
            count += 1
        avg_acc += acc

    avg_acc = avg_acc / iterations
    print(f'模型的测试集准确率：{avg_acc}')
# Out:
# C:\Users\20218\AppData\Local\Temp\ipykernel_19132\2314832960.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 模型的测试集准确率：95.9
